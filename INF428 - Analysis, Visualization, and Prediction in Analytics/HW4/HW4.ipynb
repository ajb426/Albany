# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import csv as csv
import pandas as pd
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS

# %%
plt.style.use('classic')

# %%
# %matplotlib inline

# %%
data= pd.read_csv("adult.csv")
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
x = np.linspace(0 , 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %%
fig.savefig('my_figure.png')

# %%
plt.style.use('seaborn-whitegrid')

# %%
#data
df13 = data[(data.education_num == 13)]
df13 = df13.head(100)
df14 = data[(data.education_num == 14)]
df14 = df14.head(100)
df15 = data[(data.education_num == 15)]
df15 = df15.head(100)
df16 = data[(data.education_num == 16)]
df16 = df16.head(100)

# %%
#lineplot
plt.plot(df13.capital_gain, df13.occupation, '-g', label = 'Bachelors')
plt.plot(df14.capital_gain, df14.occupation, ':b', label = 'Masters')
plt.plot(df15.capital_gain, df15.occupation, '-.k', label = 'Prof-school')
plt.plot(df16.capital_gain, df16.occupation, '--r', label = 'Doctorate')
plt.title("Capital Gain vs. Occupation by Education Level")
plt.xlabel("Capital Gain")
plt.ylabel("Occupation")
plt.xlim(0, 35000)
plt.legend()

# %%
#scatterplot
plt.plot(df13.capital_gain, df13.occupation, 'ok', label='Bachelors')
plt.plot(df14.capital_gain, df14.occupation, '<g', label = 'Masters')
plt.plot(df15.capital_gain, df15.occupation, 'xb', label = 'Prof-School')
plt.plot(df16.capital_gain, df16.occupation, 'sr', label = 'Doctorate')
plt.title("Capital Gain vs. Occupation by Education Level")
plt.xlabel("Capital Gain")
plt.ylabel("Occupation")
plt.xlim(0,35000)
plt.legend()

# %%
dfHist = data.filter(["age"], axis = 1)

# %%
#histogram
plt.hist(dfHist, bins=30, alpha=0.5,
        histtype = 'stepfilled', color='green')
# Out:
# (array([1.657e+03, 1.473e+03, 2.440e+03, 1.626e+03, 2.515e+03, 1.749e+03,
#         2.589e+03, 1.774e+03, 1.685e+03, 2.418e+03, 1.550e+03, 2.195e+03,
#         1.251e+03, 1.774e+03, 9.420e+02, 8.340e+02, 1.090e+03, 6.670e+02,
#         7.880e+02, 3.860e+02, 4.210e+02, 1.970e+02, 1.390e+02, 1.600e+02,
#         7.500e+01, 6.700e+01, 3.200e+01, 1.900e+01, 2.000e+00, 4.600e+01]),
#  array([17.        , 19.43333333, 21.86666667, 24.3       , 26.73333333,
#         29.16666667, 31.6       , 34.03333333, 36.46666667, 38.9       ,
#         41.33333333, 43.76666667, 46.2       , 48.63333333, 51.06666667,
#         53.5       , 55.93333333, 58.36666667, 60.8       , 63.23333333,
#         65.66666667, 68.1       , 70.53333333, 72.96666667, 75.4       ,
#         77.83333333, 80.26666667, 82.7       , 85.13333333, 87.56666667,
#         90.        ]),
#  [<matplotlib.patches.Polygon at 0x260b71d2070>])

# %%
dfPied = {'workclass': ['Federal-gov', 'Local-Gov', 'Never-worked', 'private','self-emp-inc', 'self-emp-not-inc', 'state-gov', 'without-pay'], 'Percent': [3,7,0.2,74,4,8,3,0.8]}
dfPie = pd.DataFrame(data=dfPied)
dfPie.head()
# Out:
#       workclass  Percent
# 0   Federal-gov      3.0
# 1     Local-Gov      7.0
# 2  Never-worked      0.2
# 3       private     74.0
# 4  self-emp-inc      4.0

# %%
#piechart
plt.pie(dfPie['Percent'], labels = dfPie['workclass'])
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#boxplot data
box = data[['capital_gain']]
box.head(100)
box.describe()
box_array = np.array(box)
box_array= box_array[box_array!=0]
box_array
# Out:
# array([ 2174, 14084,  5178, ..., 15020,  1086, 15024], dtype=int64)

# %%
#boxplot
colors = ['blue']
bp = plt.boxplot(box_array, patch_artist = True, notch = True)

for i in range(len(bp['boxes'])):
    bp['boxes'][i].set(facecolor=colors[i])
    bp['caps'][2*i + 1].set(color=colors[i])
    
plt.xticks([1], ['Capital Gain'])

plt.show()

# %%
corr = data.corr()
ax = sns.heatmap(
    corr,
    vmin=-1,vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
ax.get_xticklabels(),
rotation=45,
horizontalalignment='right')
# Out:
# [Text(0.5, 0, 'age'),
#  Text(1.5, 0, 'fnlwgt'),
#  Text(2.5, 0, 'education_num'),
#  Text(3.5, 0, 'capital_gain'),
#  Text(4.5, 0, 'capial_loss'),
#  Text(5.5, 0, 'hours_per_week'),
#  Text(6.5, 0, 'freq')]

# %%
comment_words = ''
stopwords = set(STOPWORDS)
for val in data.native_country:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
        comment_words += " ".join(tokens)+" "

        
wordcloud = WordCloud(width = 800, height = 800,
                     background_color = 'white',
                     stopwords = stopwords,
                     min_font_size = 10).generate(comment_words)
plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
